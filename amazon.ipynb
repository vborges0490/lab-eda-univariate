# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from dotenv import load_dotenv

load_dotenv()

amazon_csv = os.getenv('AMAZON_DIR')
amazon_file = os.getenv('AMAZON_FILE')


df_amazon = pd.read_csv(amazon_csv+amazon_file)

# %%
category_frequency = df_amazon['category'].value_counts()

top_5_categories = category_frequency.head(5)
print(top_5_categories)
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
top_categories = category_frequency.head(10) # Adjust this number as needed

top_categories.plot(kind='bar')
plt.title('Distribution of Products Across Top Categories')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_5_categories.plot(kind='pie', autopct='%1.1f%%')
plt.title('Proportions of Top 5 Product Categories')
plt.ylabel('') 
plt.show()

# %% [markdown]
# **Answers**
#
# 1. Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             1
#
# 2. Yes Sports & Outdoors have a huge discrepency from the rest of the categories.8978

# %%
mean_price = df_amazon['price'].mean()
median_price = df_amazon['price'].median()
mode_price = df_amazon['price'].mode()[0]

print(f"Mean Price: {mean_price}")
print(f"Median Price: {median_price}")
print(f"Mode Price: {mode_price}")
# Out:
# Mean Price: 89.24380943923663
# Median Price: 19.09
# Mode Price: 9.99

# %%
variance_price = df_amazon['price'].var()
std_deviation_price = df_amazon['price'].std()
range_price = df_amazon['price'].max() - df_amazon['price'].min()
q1 = df_amazon['price'].quantile(0.25)
q3 = df_amazon['price'].quantile(0.75)
iqr = q3 - q1

print(f"Variance: {variance_price}")
print(f"Standard Deviation: {std_deviation_price}")
print(f"Range: {range_price}")
print(f"Interquartile Range: {iqr}")
# Out:
# Variance: 119445.48532254907
# Standard Deviation: 345.60886175349884
# Range: 100000.0
# Interquartile Range: 36.0

# %%
plt.hist(df_amazon['price'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df_amazon['price'], vert=False)
plt.title('Box Plot of Product Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# **Answers**
#
# 1. The average price is 19, which when compared with mode value of 10 show that most common price is lower than the average.
#
# 2. There is a extreme discrepancy between the highest and lowest prices, which already indicate spread values. The variance also highligh it with a very high value showing a huge gap from prices and the mean showing a wide distribution of prices.
#
# 3. Yes apparently there is a value reaching price around 100000 and another around 78000 leading to wide distribuition.

# %%
mean_rating = df_amazon['stars'].mean()
median_rating = df_amazon['stars'].median()
mode_rating = df_amazon['stars'].mode()[0]

print(f"Mean Rating: {mean_rating}")
print(f"Median Rating: {median_rating}")
print(f"Mode Rating: {mode_rating}")
# Out:
# Mean Rating: 2.152836472966065
# Median Rating: 0.0
# Mode Rating: 0.0

# %%
variance_rating = df_amazon['stars'].var()
std_deviation_rating = df_amazon['stars'].std()
q1_rating = df_amazon['stars'].quantile(0.25)
q3_rating = df_amazon['stars'].quantile(0.75)
iqr_rating = q3_rating - q1_rating

print(f"Variance: {variance_rating}")
print(f"Standard Deviation: {std_deviation_rating}")
print(f"Interquartile Range: {iqr_rating}")
# Out:
# Variance: 4.817434029796862
# Standard Deviation: 2.1948653785134207
# Interquartile Range: 4.4

# %%
skewness_rating = df_amazon['stars'].skew()
kurtosis_rating = df_amazon['stars'].kurtosis()

print(f"Skewness: {skewness_rating}")
print(f"Kurtosis: {kurtosis_rating}")
# Out:
# Skewness: 0.08120735761080985
# Kurtosis: -1.9260061280432985

# %%
plt.hist(df_amazon['stars'], bins=20, color='green', edgecolor='black')
plt.title('Distribution of Product Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Answers**
#
# 1. The value of the median be 0 indicate that the majority add the rating as 0 or not add rating at all.
#
# 2. Yes looking to the Varience value it's clear that there is a wide variation in the ratings. This indicate that customers have a high difference in terms of opinion about the products.
#
# 3. Skewness is very close to 0, which indicate that is symmetrical distribution. The negative value for Kurtosis indicate that the distribution is flatter thans a normal one with fewer outliners.
#
# 4. The most common rating is 0 followed for something close to 5.
